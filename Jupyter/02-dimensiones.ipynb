# %% [markdown]
# ###  **DIMENSIONES**

# %%
import numpy as np

# %% [markdown]
# <h4 style = "color:cyan"> Generando un Array de 12 elementos enteros con Random </h4>

# %% [markdown]
# <image src="assets/img/Vectorv1.png" width=30% alt="Descripción de la imagen">

# %%
vector = np.random.randint(1,10,12)
vector
# Out:
# array([7, 1, 3, 1, 3, 1, 3, 6, 9, 4, 7, 5])

# %% [markdown]
# <h4 style = "color:cyan"> Obtener la dimensión de un arreglo </h4>

# %%
np.shape(vector)
# Out:
# (12,)

# %% [markdown]
# <h4 style = "color:cyan"> Transformación del vector de 12 elementos a Matriz 4x3 con Reshape </h4>

# %% [markdown]
# <image src="assets/img/matrix.png" width=25% alt="Descripción de la imagen">

# %%
matriz = vector.reshape(3,4)
matriz
# Out:
# array([[7, 1, 3, 1],
#        [3, 1, 3, 6],
#        [9, 4, 7, 5]])

# %% [markdown]
# <h4 style = "color:cyan">Transformación del vector de 12 elementos a Matriz 4x3 con Reshape </h4>

# %%
np.shape(matriz)
# Out:
# (3, 4)

# %% [markdown]
# <h4 style = "color:cyan"> Otra Transformación del vector de 9 elementos a Matriz 3x4 con Reshape </h4>

# %%
matriz = vector.reshape(3,4)
matriz
# Out:
# array([[7, 1, 3, 1],
#        [3, 1, 3, 6],
#        [9, 4, 7, 5]])

# %% [markdown]
# <h4 style = "color:cyan"> Creando un Tensor </h4>

# %% [markdown]
# <image src="assets/img/tensor.png" width=30% alt="Descripción de la imagen">

# %%
t = [[[[1,2,3],[4,5,6],[7,8,9],[1,2,3]]]]
t
# Out:
# [[[[1, 2, 3], [4, 5, 6], [7, 8, 9], [1, 2, 3]]]]

# %% [markdown]
# ###  **CONOCIENDO EL PAQUETE MATPLOTLIB**

# %% [markdown]
# <h4 style = "color:cyan"> Graficando el Vector Generado Anteriormente </h4>

# %%
# Importamos la biblioteca Matplotlib (Para Graficar)
import matplotlib.pyplot as plt


plt.plot(vector, label = "Vector")
plt.title("Gráfico del Vector")
plt.xlabel("Índice")
plt.ylabel("Valores")

plt.grid(True) #Agrega cuadricula

plt.legend() #Invoca propiedad label de plot

plt.show() # Para visualizar el gráfico con Python
